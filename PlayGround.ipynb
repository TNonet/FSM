# %%
import fsm
import numpy as np
import numba as nb
import random_gen
from time import time

# %%
gen_f = random_gen.test_f_matrix(m=10,k = 5, density=.2,sym=True)

# %%
array_np, array_sparse = next(gen_f)
array_np
# Out:
# array([[ 0.,  3.,  5.,  5.,  0.,  0.,  0.,  0.,  0.,  0.],
#        [ 3.,  0.,  0.,  5., 14.,  2., 12.,  0.,  3.,  2.],
#        [ 5.,  0., 12.,  5.,  0.,  2.,  0.,  0.,  7.,  0.],
#        [ 5.,  5.,  5.,  0., 16.,  0.,  0.,  0.,  0.,  3.],
#        [ 0., 14.,  0., 16.,  5.,  2.,  0.,  0.,  0.,  0.],
#        [ 0.,  2.,  2.,  0.,  2.,  0.,  0.,  0.,  0.,  0.],
#        [ 0., 12.,  0.,  0.,  0.,  0.,  0.,  7.,  9.,  3.],
#        [ 0.,  0.,  0.,  0.,  0.,  0.,  7.,  0.,  0.,  5.],
#        [ 0.,  3.,  7.,  0.,  0.,  0.,  9.,  0.,  0.,  0.],
#        [ 0.,  2.,  0.,  3.,  0.,  0.,  3.,  5.,  0.,  7.]])

# %%
fsm.eigen.power.peig(array_sparse, k=1, tol=1e-5, tol_frac=.75, max_iter=100, norm_set=2, norm_iter = 2)
# Out:
# /Users/tnonet/Documents/GitHub/FSM/fsm/eigen/power.py:96: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, A), array(float64, 1d, C))
#   u_p1 -= eig_val[j] * (eig_vec[:, j].dot(u)) * eig_vec[:, j]
# 2
# [-0.00325701  0.0024438  -0.02335376 -0.01030418  0.01806867 -0.00336119
#  -0.00475207  0.0015613  -0.0079235   0.00932217]
# [-0.1609583   0.12279596 -0.41023796  0.19623027 -0.04703271 -0.00568259
#  -0.00309022  0.01334633 -0.1989136   0.03278055]
# 4
# [-0.00646493 -0.00681652 -0.05666781 -0.02668513  0.04249724 -0.00616363
#  -0.00115086  0.00131087 -0.02332119  0.01033069]
# [-0.43721424  0.36670109 -1.02133964  0.36120153 -0.32223439 -0.04197419
#  -0.25152084  0.04359742 -0.42748198 -0.01827182]
# 6
# [-0.00253843 -0.00973354 -0.01812467 -0.01230788  0.01063307 -0.00225369
#   0.00092679 -0.00213633 -0.00958919  0.00132947]
# [-0.1813634   0.06021379 -0.36335929  0.02213439 -0.28453772 -0.03445028
# ...

# %%
val, vec = np.linalg.eig(array_np)
val[0]
# Out:
# 30.60337473771805
